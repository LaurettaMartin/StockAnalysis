# %%
pip install panda
# Out:
# ...
#   Created wheel for panda: filename=panda-0.3.1-py3-none-any.whl size=7256 sha256=94ea52dc0200a219ed3f4e890efc484e14065dcf3d3a27fc6fad4d8c414d8843
#   Stored in directory: /Users/laurettamartin/Library/Caches/pip/wheels/6c/5a/a9/a28c87238ddcc61701224f538bedccc21c9e2b8bc6fa8fca0e
# Successfully built panda
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas_datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pd.core.common.is_list_like = pd.api.types.is_list_like

# %%
from pandas_datareader import data

# %%
df = data.get_data_yahoo ('HD', '2019-01-01', '2022-01-01')

# %%
df.head()
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2019-01-02  173.179993  169.050003  169.710007  172.410004  4242900.0
# 2019-01-03  171.839996  168.210007  171.839996  168.610001  4810500.0
# 2019-01-04  174.740005  169.520004  170.179993  173.619995  4762600.0
# 2019-01-07  178.179993  173.830002  173.830002  177.039993  4928800.0
# 2019-01-08  179.589996  175.610001  178.570007  177.889999  4722400.0
#
#              Adj Close
# Date
# 2019-01-02  157.620941
# 2019-01-03  154.146896
# 2019-01-04  158.727142
# 2019-01-07  161.853745
# 2019-01-08  162.630875

# %%
pip install quandl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import quandl

# %%
hd = quandl.get("WIKI/HD", start_date = "2010-01-01", end_date = "2020-01-01")

# %%
hd.describe()
# Out:
#               Open        High          Low        Close        Volume  \
# count  2071.000000  2071.00000  2071.000000  2071.000000  2.071000e+03
# mean     88.151101    88.83594    87.481473    88.180103  8.059479e+06
# std      45.614010    45.90161    45.283887    45.596180  5.066113e+06
# min      26.750000    27.26000    26.620000    27.070000  1.517075e+06
# 25%      44.635000    44.99000    44.278750    44.640000  4.577084e+06
# 50%      79.560000    80.06000    79.090000    79.580000  6.573100e+06
# 75%     126.855000   127.59000   125.630000   126.705000  9.876300e+06
# max     207.230000   207.60500   204.710000   207.230000  4.908870e+07
#
#        Ex-Dividend  Split Ratio    Adj. Open    Adj. High     Adj. Low  \
# count  2071.000000       2071.0  2071.000000  2071.000000  2071.000000
# mean      0.006941          1.0    83.569423    84.215348    82.936017
# std       0.061764          0.0    46.813734    47.115081    46.471809
# ...

# %%
import pandas_datareader as pdr

# %%
import datetime

# %%
hd = pdr.get_data_yahoo('HD', start = datetime.datetime(2010,1,1), end = datetime.datetime(2020,1,1))

# %%
hd.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  2516.000000  2516.000000  2516.000000  2516.000000  2.516000e+03
# mean    108.647647   106.965739   107.799038   107.835135  7.434861e+06
# std      60.176469    59.296948    59.755300    59.751599  4.861907e+06
# min      27.260000    26.620001    26.750000    27.070000  1.517100e+06
# 25%      52.299999    51.414999    51.867499    51.957500  4.181875e+06
# 50%     104.254997   101.939999   103.185001   103.514999  5.912550e+06
# 75%     154.514999   152.725002   153.577503   153.424995  9.086775e+06
# max     239.309998   236.759995   238.440002   238.850006  4.908870e+07
#
#          Adj Close
# count  2516.000000
# mean     93.604143
# std      56.657086
# min      20.264923
# 25%      41.292236
# 50%      86.827492
# 75%     135.615829
# max     222.883698

# %%
hd.to_csv('hd2010to2020.csv')

# %%
download_hd = "hd2010to2020.csv"

# %%
hd['Change']=hd.Open - hd.Close

# %%
hd['Percent_Change']=hd.Change/hd.Open

# %%
import matplotlib.pyplot as plt

# %%
hd['Percent_Change'].plot(grid = True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.show()

# %%
def get(tickers, startdate, enddate):
    def data(ticker):
        return(pdr.get_data_yahoo(ticker, start = startdate, end = enddate))
    datas = map(data, tickers)
    return(pd.concat(datas, keys = tickers, names = ['Ticker', 'Date']))
tickers = ['HD', 'AMZN', 'LOW', 'GE']
all_data = get(tickers, datetime.datetime(2010,1,1), datetime.datetime(2020,1,1))

# %%
all_data
# Out:
#                         High        Low       Open      Close      Volume  \
# Ticker Date
# HD     2010-01-04  29.150000  28.549999  29.150000  28.670000  13120900.0
#        2010-01-05  28.990000  28.290001  28.730000  28.879999  15594300.0
#        2010-01-06  29.000000  28.700001  28.879999  28.780001   8833200.0
#        2010-01-07  29.219999  28.730000  28.860001  29.120001  12058200.0
#        2010-01-08  29.240000  28.690001  29.000000  28.980000  15609800.0
# ...                      ...        ...        ...        ...         ...
# GE     2019-12-24  89.599998  88.720001  88.800003  89.519997   2596125.0
#        2019-12-26  89.839996  89.040001  89.440002  89.839996   3795838.0
#        2019-12-27  89.680000  89.040001  89.360001  89.440002   3746475.0
#        2019-12-30  89.279999  88.239998  88.559998  88.639999   6018250.0
#        2019-12-31  89.279999  87.680000  88.000000  89.279999   7082250.0
#
#                    Adj Close
# Ticker Date
# ...

# %%
all_data.to_csv('HDComps.csv')
